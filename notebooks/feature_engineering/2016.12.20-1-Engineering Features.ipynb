# %% [markdown]
# # Engineering Features
#
# **Methods:**
# >1. Load data
# >2. Create feature for which deck they're on
# >3. Create feature for family size
# >4. Create features for familial status
# >5. Add procedure to src file

# %%
import sys
sys.path.append('./../../src/')
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import Data_Loader

# %% [markdown]
# ## 1. Load data

# %%
X, y = Data_Loader.load_training_data()

# %% [markdown]
# ## 2. Create feature for which deck they're on

# %%
X.head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked Deck  FamilySize
# PassengerId
# 1                  S  UNK           2
# 2                  C    C           2
# 3                  S  UNK           1
# 4                  S    C           2
# 5                  S  UNK           1

# %% [markdown]
# This will use the Cabin number: specifically, it will use the first character of the Cabin name. If it doesn't exist, we replace it with an "UNK" for unknown:

# %%
X['Deck'] = X['Cabin'].map(lambda x: str(x)[0]).replace('n', 'UNK')

# %%
X.head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked Deck
# PassengerId
# 1                  S  UNK
# 2                  C    C
# 3                  S  UNK
# 4                  S    C
# 5                  S  UNK

# %% [markdown]
# ## 3. Create feature for family size

# %% [markdown]
# The family size is the sum of the passenger's Sibsp + Parch + 1. The 1 is for themselves

# %%
X['FamilySize'] = X['SibSp'] + X['Parch'] + 1

# %%
X.head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked Deck  FamilySize
# PassengerId
# 1                  S  UNK           2
# 2                  C    C           2
# 3                  S  UNK           1
# 4                  S    C           2
# 5                  S  UNK           1

# %% [markdown]
# ## 4. Create features for familial status

# %% [markdown]
# For this, I want to determine if the person is traveling [alone, with spouse, or with family].
#
# * Alone is simple, this will be people whose family size == 1
#
# * With a spouse is a little more complex, the passenger needs to be over ~18, with 0 parch, and only 1 sibsp:
#
# * With family is everything else

# %%
X.loc[(X['SibSp'] == 1)
     & (X['Parch'] == 0)].sort_values(['Name'])
# Out:
#              Pclass                                               Name  \
# PassengerId
# 309               2                                Abelson, Mr. Samuel
# 875               2              Abelson, Mrs. Samuel (Hannah Wizosky)
# 41                3     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 193               3    Andersen-Jensen, Miss. Carla Christine Nielsine
# 276               1                  Andrews, Miss. Kornelia Theodosia
# 519               2  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 354               3                          Arnold-Franchi, Mr. Josef
# 50                3      Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# 701               1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 207               3                         Backstrom, Mr. Karl Alfred
# 544               2                                  Beane, Mr. Edward
# 547               2                  Beane, Mrs. Edward (Ethel Clarke)
# 485               1                            Bishop, Mr. Dickinson H
# 292               1            Bishop, Mrs. Dickinson H (Helen Walton)
# 478               3                          Braund, Mr. Lewis Richard
# 1                 3                            Braund, Mr. Owen Harris
# 729               2                    Bryhl, Mr. Kurt Arnold Gottfrid
# 579               3                   Caram, Mrs. Joseph (Maria Elias)
# 855               2      Carter, Mrs. Ernest Courtenay (Lilian Hughes)
# 250               2                      Carter, Rev. Ernest Courtenay
# 742               1                      Cavendish, Mr. Tyrell William
# 93                1                        Chaffee, Mr. Herbert Fuller
# 725               1                      Chambers, Mr. Norman Campbell
# 810               1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 595               2                            Chapman, Mr. John Henry
# 74                3                        Chronopoulos, Mr. Apostolos
# 427               2        Clarke, Mrs. Charles V (Ada Maria Winfield)
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 672               1                             Davidson, Mr. Thornton
# 348               3          Davison, Mrs. Thomas Henry (Mary E Finck)
# ...             ...                                                ...
# 187               3    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)
# 337               1                          Pears, Mr. Thomas Clinton
# 152               1                  Pears, Mrs. Thomas (Edith Wearne)
# 506               1         Penasco y Castellana, Mr. Victor de Satode
# 308               1  Penasco y Castellana, Mrs. Victor de Satode (M...
# 268               3                           Persson, Mr. Ernst Ulrik
# 443               3                          Petterson, Mr. Johan Emil
# 477               2                            Renouf, Mr. Peter Henry
# 133               3     Robins, Mrs. Alexander A (Grace Charity Laury)
# 514               1     Rothschild, Mrs. Martin (Elizabeth L. Barrett)
# 435               1                          Silvey, Mr. William Baird
# 578               1          Silvey, Mrs. William Baird (Alice Munger)
# 32                1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 592               1    Stephenson, Mrs. Walter Bertram (Martha Eustis)
# 713               1                           Taylor, Mr. Elmer Zebley
# 670               1  Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)
# 640               3                         Thorneycroft, Mr. Percival
# 432               3  Thorneycroft, Mrs. Percival (Florence Kate White)
# 118               2                    Turpin, Mr. William John Robert
# 42                2  Turpin, Mrs. William John Robert (Dorothy Ann ...
# 19                3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 367               1   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# 134               2      Weisz, Mrs. Leopold (Mathilde Francoise Pede)
# 372               3                          Wiklund, Mr. Jakob Alfred
# 621               3                                Yasbeck, Mr. Antoni
# 831               3            Yasbeck, Mrs. Antoni (Selini Alexander)
# 112               3                               Zabour, Miss. Hileni
# 241               3                              Zabour, Miss. Thamine
# 560               3       de Messemaeker, Mrs. Guillaume Joseph (Emma)
# 362               2                          del Carlo, Mr. Sebastiano
#
#                 Sex   Age  SibSp  Parch         Ticket      Fare    Cabin  \
# PassengerId
# 309            male  30.0      1      0      P/PP 3381   24.0000      NaN
# 875          female  28.0      1      0      P/PP 3381   24.0000      NaN
# 41           female  40.0      1      0           7546    9.4750      NaN
# 193          female  19.0      1      0         350046    7.8542      NaN
# 276          female  63.0      1      0          13502   77.9583       D7
# 519          female  36.0      1      0         226875   26.0000      NaN
# 354            male  25.0      1      0         349237   17.8000      NaN
# 50           female  18.0      1      0         349237   17.8000      NaN
# 701          female  18.0      1      0       PC 17757  227.5250  C62 C64
# 207            male  32.0      1      0        3101278   15.8500      NaN
# 544            male  32.0      1      0           2908   26.0000      NaN
# 547          female  19.0      1      0           2908   26.0000      NaN
# 485            male  25.0      1      0          11967   91.0792      B49
# 292          female  19.0      1      0          11967   91.0792      B49
# 478            male  29.0      1      0           3460    7.0458      NaN
# 1              male  22.0      1      0      A/5 21171    7.2500      NaN
# 729            male  25.0      1      0         236853   26.0000      NaN
# 579          female   NaN      1      0           2689   14.4583      NaN
# 855          female  44.0      1      0         244252   26.0000      NaN
# 250            male  54.0      1      0         244252   26.0000      NaN
# 742            male  36.0      1      0          19877   78.8500      C46
# 93             male  46.0      1      0    W.E.P. 5734   61.1750      E31
# 725            male  27.0      1      0         113806   53.1000       E8
# 810          female  33.0      1      0         113806   53.1000       E8
# 595            male  37.0      1      0    SC/AH 29037   26.0000      NaN
# 74             male  26.0      1      0           2680   14.4542      NaN
# 427          female  28.0      1      0           2003   26.0000      NaN
# 2            female  38.0      1      0       PC 17599   71.2833      C85
# 672            male  31.0      1      0     F.C. 12750   52.0000      B71
# 348          female   NaN      1      0         386525   16.1000      NaN
# ...             ...   ...    ...    ...            ...       ...      ...
# 187          female   NaN      1      0         370365   15.5000      NaN
# 337            male  29.0      1      0         113776   66.6000       C2
# 152          female  22.0      1      0         113776   66.6000       C2
# 506            male  18.0      1      0       PC 17758  108.9000      C65
# 308          female  17.0      1      0       PC 17758  108.9000      C65
# 268            male  25.0      1      0         347083    7.7750      NaN
# 443            male  25.0      1      0         347076    7.7750      NaN
# 477            male  34.0      1      0          31027   21.0000      NaN
# 133          female  47.0      1      0      A/5. 3337   14.5000      NaN
# 514          female  54.0      1      0       PC 17603   59.4000      NaN
# 435            male  50.0      1      0          13507   55.9000      E44
# 578          female  39.0      1      0          13507   55.9000      E44
# 32           female   NaN      1      0       PC 17569  146.5208      B78
# 592          female  52.0      1      0          36947   78.2667      D20
# 713            male  48.0      1      0          19996   52.0000     C126
# 670          female   NaN      1      0          19996   52.0000     C126
# 640            male   NaN      1      0         376564   16.1000      NaN
# 432          female   NaN      1      0         376564   16.1000      NaN
# 118            male  29.0      1      0          11668   21.0000      NaN
# 42           female  27.0      1      0          11668   21.0000      NaN
# 19           female  31.0      1      0         345763   18.0000      NaN
# 367          female  60.0      1      0         110813   75.2500      D37
# 134          female  29.0      1      0         228414   26.0000      NaN
# 372            male  18.0      1      0        3101267    6.4958      NaN
# 621            male  27.0      1      0           2659   14.4542      NaN
# 831          female  15.0      1      0           2659   14.4542      NaN
# 112          female  14.5      1      0           2665   14.4542      NaN
# 241          female   NaN      1      0           2665   14.4542      NaN
# 560          female  36.0      1      0         345572   17.4000      NaN
# 362            male  29.0      1      0  SC/PARIS 2167   27.7208      NaN
#
#             Embarked Deck  FamilySize
# PassengerId
# 309                C  UNK           2
# 875                C  UNK           2
# 41                 S  UNK           2
# 193                S  UNK           2
# 276                S    D           2
# 519                S  UNK           2
# 354                S  UNK           2
# 50                 S  UNK           2
# 701                C    C           2
# 207                S  UNK           2
# 544                S  UNK           2
# 547                S  UNK           2
# 485                C    B           2
# 292                C    B           2
# 478                S  UNK           2
# 1                  S  UNK           2
# 729                S  UNK           2
# 579                C  UNK           2
# 855                S  UNK           2
# 250                S  UNK           2
# 742                S    C           2
# 93                 S    E           2
# 725                S    E           2
# 810                S    E           2
# 595                S  UNK           2
# 74                 C  UNK           2
# 427                S  UNK           2
# 2                  C    C           2
# 672                S    B           2
# 348                S  UNK           2
# ...              ...  ...         ...
# 187                Q  UNK           2
# 337                S    C           2
# 152                S    C           2
# 506                C    C           2
# 308                C    C           2
# 268                S  UNK           2
# 443                S  UNK           2
# 477                S  UNK           2
# 133                S  UNK           2
# 514                C  UNK           2
# 435                S    E           2
# 578                S    E           2
# 32                 C    B           2
# 592                C    D           2
# 713                S    C           2
# 670                S    C           2
# 640                S  UNK           2
# 432                S  UNK           2
# 118                S  UNK           2
# 42                 S  UNK           2
# 19                 S  UNK           2
# 367                C    D           2
# 134                S  UNK           2
# 372                S  UNK           2
# 621                C  UNK           2
# 831                C  UNK           2
# 112                C  UNK           2
# 241                C  UNK           2
# 560                S  UNK           2
# 362                C  UNK           2
#
# [123 rows x 12 columns]

# %%
X.loc[(X['SibSp'] == 1)
     & (X['Parch'] == 0), 'Age'].dropna().map(lambda x: x >= 18).mean()
# Out:
# 0.92156862745098034

# %% [markdown]
# 92% of people with 1 sibling and 0 parents are over 18 years old

# %%
def get_familial_status(passenger_data):
    try:
    if (passenger_data['SibSp'] == 1 
        & passenger_data['Parch'] == 0
        & passenger_data['Age'] >= 18):
        return 'with_spouse'
    elif passenger_data['FamilySize'] == 0:
        return 'single'
    else:
        return 'with_family'

# %%
X.apply(get_familial_status, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a27d4aab7e61> in <module>()
# ----> 1 X.apply(get_familial_status, axis=1)
#
# /home/lundi/.virtualenvs/default_venv/local/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4059                     if reduce is None:
#    4060                         reduce = True
# -> 4061                     return self._apply_standard(f, axis, reduce=reduce)
#    4062             else:
#    4063                 return self._apply_broadcast(f, axis)
#
# /home/lundi/.virtualenvs/default_venv/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4155             try:
#    4156                 for i, v in enumerate(series_gen):
# -> 4157                     results[i] = func(v)
#    4158                     keys.append(v.name)
#    4159             except Exception as e:
#
# <ipython-input-32-91e5982247c2> in get_familial_status(passenger_data)
#       2     if (passenger_data['SibSp'] == 1
#       3         & passenger_data['Parch'] == 0
# ----> 4         & passenger_data['Age'] >= 18):
#       5         return 'with_spouse'
#       6     elif passenger_data['FamilySize'] == 0:
#
# TypeError: ("unsupported operand type(s) for &: 'int' and 'float'", u'occurred at index 3')

# %% [markdown]
# This is more complex than anticipated. I believe it's possible but will take time

# %% [markdown]
# ### Exporting data

# %%
X['Survived'] = y

# %%
X.to_csv('./../../data/feature_data/train_with_fam_deck.csv')

# %% [markdown]
# ## 5. Add procedure to src file
